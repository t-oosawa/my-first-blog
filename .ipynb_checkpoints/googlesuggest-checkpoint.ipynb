# %%
import argparse
from time import sleep
from string import ascii_lowercase
from string import digits
import requests
import urllib.parse


class GoogleAutoComplete:
    def __init__(self, test_mode=False, recurse_mode=False):
        self.base_url = 'https://www.google.co.jp/complete/search?'\
                        'hl=ja&output=toolbar&ie=utf-8&oe=utf-8&'\
                        'client=firefox&q='
        self.test_mode = test_mode
        self.recurse_mode = recurse_mode

        a = open('table_hiragana.dat','r',encoding="utf-8_sig")
        tango_list = []
        for tango in a:
            tango = tango.rstrip()
            tango_list.append(tango)

        if test_mode:
            self.chrs = ['あ', 'g', '1']

        else:

            self.chrs  = [str(i) for i in tango_list] # Perlの五十音のファイルと全く同じ



    def get_suggest(self, query):
        buf = requests.get(self.base_url +
                           urllib.parse.quote_plus(query)).json()
        suggests = [ph for ph in buf[1]]
        print("query: [{0}]({1})".format(query, len(suggests)))
        for ph in suggests:
            print(" ", ph)
        sleep(1)
        return suggests

    def get_suggest_with_one_char(self, query):
        # キーワードそのものの場合のサジェストワード
        ret = self.get_suggest(query)

        # キーワード＋空白の場合のサジェストワード
        ret.extend(self.get_suggest(query + ' '))

        # キーワード＋空白＋1文字の場合のサジェストワード
        for ch in self.chrs:
            ret.extend(self.get_suggest(query + ' ' + ch))

        """# -rオプションがあればもう1段階
        if self.recurse_mode:
            ret = self.get_uniq(ret)  # 事前に重複を除いておく
            addonelevel = []
            for ph in ret:
                addonelevel.extend(self.get_suggest(ph + ' '))
            ret.extend(addonelevel)"""

        return self.get_uniq(ret)

    # 重複を除く
    def get_uniq(self, arr):
        uniq_ret = []
        for x in arr:
            if x not in uniq_ret:
                uniq_ret.append(x)
        return uniq_ret

if __name__ == "__main__":
    phrase = input('please input query.')
    # Google Suggest キーワード取得
    gs = GoogleAutoComplete(recurse_mode = "--recure")
    ret = gs.get_suggest_with_one_char(phrase)


    # ファイルに保存する
    fname = "suggest.csv"
    with open(fname, 'w', encoding="utf-8_sig") as fs:
        for key in ret:
            fs.write(key + "\n")
# Out:
# please input query.大阪デリバリー㈱
# query: [大阪デリバリー㈱](0)
# query: [大阪デリバリー㈱ ](0)
# query: [大阪デリバリー㈱ あ](0)
# query: [大阪デリバリー㈱ い](0)
# query: [大阪デリバリー㈱ う](0)
# query: [大阪デリバリー㈱ え](0)
# query: [大阪デリバリー㈱ お](0)
# query: [大阪デリバリー㈱ か](0)
# query: [大阪デリバリー㈱ き](0)
# query: [大阪デリバリー㈱ く](0)
# query: [大阪デリバリー㈱ け](0)
# query: [大阪デリバリー㈱ こ](0)
# query: [大阪デリバリー㈱ さ](0)
# query: [大阪デリバリー㈱ し](0)
# query: [大阪デリバリー㈱ す](0)
# query: [大阪デリバリー㈱ せ](0)
# query: [大阪デリバリー㈱ そ](0)
# query: [大阪デリバリー㈱ た](0)
# query: [大阪デリバリー㈱ ち](0)
# query: [大阪デリバリー㈱ つ](0)
# query: [大阪デリバリー㈱ て](0)
# query: [大阪デリバリー㈱ と](0)
# query: [大阪デリバリー㈱ な](0)
# query: [大阪デリバリー㈱ に](0)
# query: [大阪デリバリー㈱ ぬ](0)
# query: [大阪デリバリー㈱ ね](0)
# query: [大阪デリバリー㈱ の](0)
# query: [大阪デリバリー㈱ は](0)
# query: [大阪デリバリー㈱ ひ](0)
# query: [大阪デリバリー㈱ ふ](0)
# query: [大阪デリバリー㈱ へ](0)
# query: [大阪デリバリー㈱ ほ](0)
# query: [大阪デリバリー㈱ ま](0)
# query: [大阪デリバリー㈱ み](0)
# query: [大阪デリバリー㈱ む](0)
# query: [大阪デリバリー㈱ め](0)
# query: [大阪デリバリー㈱ も](0)
# query: [大阪デリバリー㈱ や](0)
# query: [大阪デリバリー㈱ ゆ](0)
# query: [大阪デリバリー㈱ よ](0)
# query: [大阪デリバリー㈱ ら](0)
# query: [大阪デリバリー㈱ り](0)
# query: [大阪デリバリー㈱ る](0)
# query: [大阪デリバリー㈱ れ](0)
# query: [大阪デリバリー㈱ ろ](0)
# query: [大阪デリバリー㈱ わ](0)
# query: [大阪デリバリー㈱ を](0)
# query: [大阪デリバリー㈱ ん](0)
# query: [大阪デリバリー㈱ が](0)
# query: [大阪デリバリー㈱ ぎ](0)
# query: [大阪デリバリー㈱ ぐ](0)
# query: [大阪デリバリー㈱ げ](0)
# query: [大阪デリバリー㈱ ご](0)
# query: [大阪デリバリー㈱ ざ](0)
# query: [大阪デリバリー㈱ じ](0)
# query: [大阪デリバリー㈱ ず](0)
# query: [大阪デリバリー㈱ ぜ](0)
# query: [大阪デリバリー㈱ ぞ](0)
# query: [大阪デリバリー㈱ だ](0)
# query: [大阪デリバリー㈱ ぢ](0)
# query: [大阪デリバリー㈱ づ](0)
# query: [大阪デリバリー㈱ で](0)
# query: [大阪デリバリー㈱ ど](0)
# query: [大阪デリバリー㈱ ば](0)
# query: [大阪デリバリー㈱ び](0)
# query: [大阪デリバリー㈱ ぶ](0)
# query: [大阪デリバリー㈱ べ](0)
# query: [大阪デリバリー㈱ ぼ](0)
# query: [大阪デリバリー㈱ ぱ](0)
# query: [大阪デリバリー㈱ ぴ](0)
# query: [大阪デリバリー㈱ ぷ](0)
# query: [大阪デリバリー㈱ ぺ](0)
# query: [大阪デリバリー㈱ ぽ](0)
# query: [大阪デリバリー㈱ きゃ](0)
# query: [大阪デリバリー㈱ きゅ](0)
# query: [大阪デリバリー㈱ きょ](0)
# query: [大阪デリバリー㈱ しゃ](0)
# query: [大阪デリバリー㈱ しゅ](0)
# query: [大阪デリバリー㈱ しょ](0)
# query: [大阪デリバリー㈱ ちゃ](0)
# query: [大阪デリバリー㈱ ちゅ](0)
# query: [大阪デリバリー㈱ ちょ](0)
# query: [大阪デリバリー㈱ にゃ](0)
# query: [大阪デリバリー㈱ にゅ](0)
# query: [大阪デリバリー㈱ にょ](0)
# query: [大阪デリバリー㈱ ひゃ](0)
# query: [大阪デリバリー㈱ ひゅ](0)
# query: [大阪デリバリー㈱ ひょ](0)
# query: [大阪デリバリー㈱ みゃ](0)
# query: [大阪デリバリー㈱ みゅ](0)
# query: [大阪デリバリー㈱ みょ](0)
# query: [大阪デリバリー㈱ りゃ](0)
# query: [大阪デリバリー㈱ りゅ](0)
# query: [大阪デリバリー㈱ りょ](0)
# query: [大阪デリバリー㈱ ぎゃ](0)
# query: [大阪デリバリー㈱ ぎゅ](0)
# query: [大阪デリバリー㈱ ぎょ](0)
# query: [大阪デリバリー㈱ じゃ](0)
# query: [大阪デリバリー㈱ じゅ](0)
# query: [大阪デリバリー㈱ じょ](0)
# query: [大阪デリバリー㈱ びゃ](0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-879438879a23> in <module>
#      73     # Google Suggest キーワード取得
#      74     gs = GoogleAutoComplete(recurse_mode = "--recure")
# ---> 75     ret = gs.get_suggest_with_one_char(phrase)
#      76
#      77
#
# <ipython-input-1-879438879a23> in get_suggest_with_one_char(self, query)
#      49         # キーワード＋空白＋1文字の場合のサジェストワード
#      50         for ch in self.chrs:
# ---> 51             ret.extend(self.get_suggest(query + ' ' + ch))
#      52
#      53         """# -rオプションがあればもう1段階
#
# <ipython-input-1-879438879a23> in get_suggest(self, query)
#      37         for ph in suggests:
#      38             print(" ", ph)
# ---> 39         sleep(1)
#      40         return suggests
#      41
#
# KeyboardInterrupt:
